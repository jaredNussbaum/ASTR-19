# %%
import numpy as np
import matplotlib.pyplot as plt

random_numbers = np.random.poisson(lam=5, size=1000)

plt.figure(figsize=(5, 5))

plt.hist(random_numbers, bins=100)

plt.xlabel('Value')
plt.ylabel('Count')

plt.savefig('journal4output')
plt.show()
